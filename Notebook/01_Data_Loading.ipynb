# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\galim\\Documents\\scRNA_project'

# %%
import scanpy as sc
print(sc.__version__)
# Out:
# 1.11.5
# C:\Users\galim\AppData\Local\Temp\ipykernel_19660\289967954.py:2: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   print(sc.__version__)
